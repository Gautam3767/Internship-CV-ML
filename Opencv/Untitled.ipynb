# %%
import os
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
image_path = os.path.join('.', 'data', 'bird.jpg')

# %%
img = cv2.imread(image_path)
# Out:
# array([[[126, 124,  83],
#         [127, 125,  84],
#         [127, 125,  84],
#         ...,
#         [114, 129,  74],
#         [114, 129,  74],
#         [113, 128,  73]],
#
#        [[126, 124,  83],
#         [127, 125,  84],
#         [127, 125,  84],
#         ...,
#         [114, 129,  74],
#         [114, 129,  74],
#         [113, 128,  73]],
#
#        [[126, 124,  83],
#         [126, 124,  83],
#         [127, 125,  84],
#         ...,
#         [114, 129,  74],
#         [114, 129,  74],
#         [113, 128,  73]],
#
#        ...,
#
#        [[151, 139,  99],
#         [150, 138,  98],
#         [150, 138,  98],
#         ...,
#         [133, 106,  87],
#         [141, 112,  94],
#         [126,  97,  79]],
#
#        [[151, 139,  99],
#         [150, 138,  98],
#         [150, 138,  98],
#         ...,
#         [177, 151, 128],
#         [174, 146, 125],
#         [172, 141, 120]],
#
#        [[151, 139,  99],
#         [151, 139,  99],
#         [150, 138,  98],
#         ...,
#         [156, 130, 105],
#         [196, 168, 146],
#         [184, 156, 132]]], dtype=uint8)

# %%
if img is None:
    sys.exit("Could not read the image.")
cv2.imshow(img)

# %%
cv2.destroyAllWindows()

# %%
cv2.imwrite(os.path.join('.', 'data', 'bird_out.jpg'), img)
# Out:
# True
