# %% [markdown]
# <a href="https://colab.research.google.com/github/Gautam3767/Internship-Week-3/blob/main/flowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1a1df1d-8ce9-48ae-9d41-8e69f364c523" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1a1df1d-8ce9-48ae-9d41-8e69f364c523">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d alxmamaev/flowers-recognition
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alxmamaev/flowers-recognition
# License(s): unknown
# ...
#  97% 217M/225M [00:02<00:00, 92.4MB/s]
# 100% 225M/225M [00:02<00:00, 90.0MB/s]

# %%
import zipfile
import os
with zipfile.ZipFile('flowers-recognition.zip', 'r') as zip_ref:
    zip_ref.extractall('flowers-recognition')
# with zipfile.ZipFile('flowers-recognition/train.zip', 'r') as zip_ref:
#     zip_ref.extractall('flowers-recognition/train')

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def laod_and_display_images(folder_path,num_images=10):
  images = os.listdir(folder_path)[:num_images]
  plt.figure(figsize=(10,10))

  for i, image_name in enumerate(images):
    image_path = os.path.join(folder_path,image_name)
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.subplot(1,num_images,i+1)
    plt.imshow(image)
    plt.axis('off')
  plt.show

# %%
image_path = 'flowers-recognition/flowers/daisy'
laod_and_display_images(image_path, num_images = 10)

# %%
image_path = 'flowers-recognition/flowers/rose'
laod_and_display_images(image_path, num_images = 10)
